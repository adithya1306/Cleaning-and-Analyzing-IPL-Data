# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
match_df=pd.read_csv("matches.csv")

# %%
match_df.sample(10)
# Out:
#        id    Season         city        date                team1  \
# 338   339  IPL-2012         Pune  24-04-2012        Pune Warriors
# 261   262  IPL-2011      Chennai  25-04-2011  Chennai Super Kings
# 643  7901  IPL-2018    Bengaluru  13-04-2018      Kings XI Punjab
# 193   194  IPL-2010       Mumbai  25-03-2010  Chennai Super Kings
# 222   223  IPL-2010       Jaipur  14-04-2010     Rajasthan Royals
# 578   579  IPL-2016   Chandigarh  11-04-2016      Kings XI Punjab
# 662  7920  IPL-2018         Pune  28-04-2018  Chennai Super Kings
# 608   609  IPL-2016        Delhi  05-05-2016     Delhi Daredevils
# 231   232  IPL-2010       Mumbai  22-04-2010  Chennai Super Kings
# 143   144  IPL-2009  East London  04-05-2009  Chennai Super Kings
#
#                            team2                  toss_winner toss_decision  \
# 338             Delhi Daredevils                Pune Warriors           bat
# 261                Pune Warriors                Pune Warriors         field
# ...

# %%
match_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
match_df.shape
# Out:
# (756, 18)

# %%
## read the other file

dlvr_df=pd.read_csv("deliveries.csv")

# %%
dlvr_df.tail()
# Out:
#         match_id  inning         batting_team    bowling_team  over  ball  \
# 179073     11415       2  Chennai Super Kings  Mumbai Indians    20     2
# 179074     11415       2  Chennai Super Kings  Mumbai Indians    20     3
# 179075     11415       2  Chennai Super Kings  Mumbai Indians    20     4
# 179076     11415       2  Chennai Super Kings  Mumbai Indians    20     5
# 179077     11415       2  Chennai Super Kings  Mumbai Indians    20     6
#
#           batsman non_striker      bowler  is_super_over  ...  bye_runs  \
# 179073  RA Jadeja   SR Watson  SL Malinga              0  ...         0
# 179074  SR Watson   RA Jadeja  SL Malinga              0  ...         0
# 179075  SR Watson   RA Jadeja  SL Malinga              0  ...         0
# 179076  SN Thakur   RA Jadeja  SL Malinga              0  ...         0
# 179077  SN Thakur   RA Jadeja  SL Malinga              0  ...         0
#
#         legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
dlvr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %% [markdown]
# ## Total score in every inning in every match

# %%
dlvr_df.groupby(['match_id','inning']).sum()['total_runs']
# Out:
# match_id  inning
# 1         1         207
#           2         172
# 2         1         184
#           2         187
# 3         1         183
#                    ...
# 11413     2         170
# 11414     1         155
#           2         162
# 11415     1         152
#           2         157
# Name: total_runs, Length: 1528, dtype: int64

# %%
inn_score = dlvr_df.groupby(['match_id','inning']).sum()['total_runs'].reset_index()

# %%
inn_score.head()
# Out:
#    match_id  inning  total_runs
# 0         1       1         207
# 1         1       2         172
# 2         2       1         184
# 3         2       2         187
# 4         3       1         183

# %%
inn_score = inn_score[inn_score['inning']==1]

# %%
inn_score.head()
# Out:
#    match_id  inning  total_runs
# 0         1       1         207
# 2         2       1         184
# 4         3       1         183
# 6         4       1         163
# 8         5       1         157

# %% [markdown]
# ## Merging with match file

# %%
match_df = match_df.merge(inn_score[['match_id','total_runs']],left_on='id',right_on='match_id')

# %%
match_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 756 entries, 0 to 755
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
match_df.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
match_df['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
match_df['team1'] = match_df['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

# %%
match_df['team2'] = match_df['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

# %%
match_df['team1'] = match_df['team1'].str.replace('Delhi Daredevils','Delhi Capitals')

# %%
match_df['team2'] = match_df['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

# %%
teams = ['Chennai Super Kings',"Delhi Capitals",'Sunrisers Hyderabad','Royal Challengers Bangalore','Punjab Kings','Rajasthan Royals','Mumbai Indians','Kolkata Knight Riders']

# %%
match_df = match_df[match_df['team1'].isin(teams)]

# %%
match_df = match_df[match_df['team2'].isin(teams)]

# %%
match_df = match_df[match_df['dl_applied']==0]

# %%
match_df.shape
# Out:
# (595, 20)

# %% [markdown]
# ## Getting rid of redundant columns

# %%
match_df = match_df[['match_id','city','winner','total_runs']]

# %%
match_df
# Out:
#      match_id           city                       winner  total_runs
# 0           1      Hyderabad          Sunrisers Hyderabad         207
# 2           3         Rajkot        Kolkata Knight Riders         183
# 4           5      Bangalore  Royal Challengers Bangalore         157
# 5           6      Hyderabad          Sunrisers Hyderabad         135
# 6           7         Mumbai               Mumbai Indians         178
# ..        ...            ...                          ...         ...
# 751     11347         Mumbai               Mumbai Indians         143
# 752     11412        Chennai               Mumbai Indians         136
# 753     11413  Visakhapatnam               Delhi Capitals         171
# 754     11414  Visakhapatnam          Chennai Super Kings         155
# 755     11415      Hyderabad               Mumbai Indians         152
#
# [595 rows x 4 columns]

# %% [markdown]
# ## Match status in 2nd innings

# %%
## feature engineering.....creating new columns like runs and balls left

# %%
dlvr_df = match_df.merge(dlvr_df, on='match_id')

# %%
dlvr_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 0              1  Hyderabad  Sunrisers Hyderabad           207       1
# 1              1  Hyderabad  Sunrisers Hyderabad           207       1
# 2              1  Hyderabad  Sunrisers Hyderabad           207       1
# 3              1  Hyderabad  Sunrisers Hyderabad           207       1
# 4              1  Hyderabad  Sunrisers Hyderabad           207       1
# ...          ...        ...                  ...           ...     ...
# 141978     11415  Hyderabad       Mumbai Indians           152       2
# 141979     11415  Hyderabad       Mumbai Indians           152       2
# 141980     11415  Hyderabad       Mumbai Indians           152       2
# 141981     11415  Hyderabad       Mumbai Indians           152       2
# 141982     11415  Hyderabad       Mumbai Indians           152       2
#
#                batting_team                 bowling_team  over  ball  \
# ...

# %%
## filter it for 2nd innings

dlvr_df=dlvr_df[dlvr_df['inning']==2]

# %%
dlvr_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 141978     11415  Hyderabad       Mumbai Indians           152       2
# 141979     11415  Hyderabad       Mumbai Indians           152       2
# 141980     11415  Hyderabad       Mumbai Indians           152       2
# 141981     11415  Hyderabad       Mumbai Indians           152       2
# 141982     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %% [markdown]
# ## Add current score

# %%
#Using cummulative sum
dlvr_df['current_score'] = dlvr_df.groupby('match_id').cumsum()['total_runs_y']

# %%
dlvr_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... legbye_runs noball_runs  penalty_runs  batsman_runs  \
# 125       CH Gayle  ...           0           0             0             1
# ...

# %%
dlvr_df['runs_left'] = dlvr_df['total_runs_x'] - dlvr_df['current_score']

# %%
dlvr_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... noball_runs penalty_runs  batsman_runs  extra_runs  \
# 125       CH Gayle  ...           0            0             1           0
# ...

# %%
dlvr_df['balls_left'] = 120 - ((dlvr_df['over']-1)*6 + dlvr_df['ball'])

# %%
dlvr_df.sample()
# Out:
#         match_id    city            winner  total_runs_x  inning  \
# 134852     11318  Mumbai  Rajasthan Royals           191       2
#
#             batting_team    bowling_team  over  ball    batsman  ...  \
# 134852  Rajasthan Royals  Mumbai Indians     3     2  AM Rahane  ...
#
#        penalty_runs batsman_runs  extra_runs  total_runs_y  player_dismissed  \
# 134852            0            1           0             1               NaN
#
#         dismissal_kind  fielder  current_score  runs_left  balls_left
# 134852             NaN      NaN             17        174         106
#
# [1 rows x 27 columns]

# %% [markdown]
# ## Wickets in hand

# %%
dlvr_df['player_dismissed'].value_counts()
# Out:
# G Gambhir     70
# RG Sharma     68
# V Kohli       67
# RV Uthappa    65
# SR Watson     59
#               ..
# LPC Silva      1
# SA Abbott      1
# M Wood         1
# K Paul         1
# MS Wade        1
# Name: player_dismissed, Length: 383, dtype: int64

# %%
dlvr_df['player_dismissed'] = dlvr_df['player_dismissed'].fillna("0")
dlvr_df['player_dismissed'] = dlvr_df['player_dismissed'].apply(lambda x:x if x=="0" else "1")
dlvr_df['player_dismissed'] = dlvr_df['player_dismissed'].astype('int')

# %%
dlvr_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... penalty_runs batsman_runs  extra_runs  total_runs_y  \
# 125       CH Gayle  ...            0            1           0             1
# ...

# %%
wkts = dlvr_df.groupby(['match_id']).cumsum()['player_dismissed'].values

# %%
wkts
# Out:
# array([0, 0, 0, ..., 6, 6, 7])

# %%
dlvr_df['wickets'] = 10 - wkts

# %%
dlvr_df.tail()
# Out:
#         match_id       city          winner  total_runs_x  inning  \
# 141978     11415  Hyderabad  Mumbai Indians           152       2
# 141979     11415  Hyderabad  Mumbai Indians           152       2
# 141980     11415  Hyderabad  Mumbai Indians           152       2
# 141981     11415  Hyderabad  Mumbai Indians           152       2
# 141982     11415  Hyderabad  Mumbai Indians           152       2
#
#                batting_team    bowling_team  over  ball    batsman  ...  \
# 141978  Chennai Super Kings  Mumbai Indians    20     2  RA Jadeja  ...
# 141979  Chennai Super Kings  Mumbai Indians    20     3  SR Watson  ...
# 141980  Chennai Super Kings  Mumbai Indians    20     4  SR Watson  ...
# 141981  Chennai Super Kings  Mumbai Indians    20     5  SN Thakur  ...
# 141982  Chennai Super Kings  Mumbai Indians    20     6  SN Thakur  ...
#
#        batsman_runs extra_runs  total_runs_y  player_dismissed  \
# 141978            1          0             1                 0
# ...

# %% [markdown]
# ## CRR

# %%
dlvr_df['crr'] = (dlvr_df['current_score']*6) / (120 - dlvr_df['balls_left'])

# %%
dlvr_df
# Out:
#         match_id       city               winner  total_runs_x  inning  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207       2
# 126            1  Hyderabad  Sunrisers Hyderabad           207       2
# 127            1  Hyderabad  Sunrisers Hyderabad           207       2
# 128            1  Hyderabad  Sunrisers Hyderabad           207       2
# 129            1  Hyderabad  Sunrisers Hyderabad           207       2
# ...          ...        ...                  ...           ...     ...
# 141978     11415  Hyderabad       Mumbai Indians           152       2
# 141979     11415  Hyderabad       Mumbai Indians           152       2
# 141980     11415  Hyderabad       Mumbai Indians           152       2
# 141981     11415  Hyderabad       Mumbai Indians           152       2
# 141982     11415  Hyderabad       Mumbai Indians           152       2
#
#                        batting_team         bowling_team  over  ball  \
# ...

# %% [markdown]
# ## Req. RR

# %%
dlvr_df['rrr'] = (dlvr_df['runs_left']*6) / dlvr_df['balls_left']

# %%
dlvr_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... total_runs_y player_dismissed  dismissal_kind  \
# 125       CH Gayle  ...            1                0             NaN
# ...

# %% [markdown]
# ## Did the team batting in the 2nd inning win or not?

# %%
def match_result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

# %%
dlvr_df['result'] = dlvr_df.apply(match_result,axis=1)

# %%
dlvr_df.sample()
# Out:
#         match_id     city               winner  total_runs_x  inning  \
# 106053       563  Chennai  Chennai Super Kings           157       2
#
#             batting_team         bowling_team  over  ball    batsman  ...  \
# 106053  Rajasthan Royals  Chennai Super Kings    16     1  SV Samson  ...
#
#        player_dismissed dismissal_kind  fielder  current_score  runs_left  \
# 106053                0            NaN      NaN             94         63
#
#         balls_left  wickets       crr        rrr  result
# 106053          29        5  6.197802  13.034483       0
#
# [1 rows x 31 columns]

# %% [markdown]
# ## Final step of cleaning

# %%
final_df = dlvr_df[['batting_team','bowling_team','city','runs_left','balls_left','wickets','total_runs_x','crr','rrr','result']]

# %%
final_df.tail()
# Out:
#                batting_team    bowling_team       city  runs_left  balls_left  \
# 141978  Chennai Super Kings  Mumbai Indians  Hyderabad          0           4
# 141979  Chennai Super Kings  Mumbai Indians  Hyderabad         -2           3
# 141980  Chennai Super Kings  Mumbai Indians  Hyderabad         -3           2
# 141981  Chennai Super Kings  Mumbai Indians  Hyderabad         -5           1
# 141982  Chennai Super Kings  Mumbai Indians  Hyderabad         -5           0
#
#         wickets  total_runs_x       crr   rrr  result
# 141978        5           152  7.862069   0.0       0
# 141979        5           152  7.897436  -4.0       0
# 141980        4           152  7.881356  -9.0       0
# 141981        4           152  7.915966 -30.0       0
# 141982        3           152  7.850000  -inf       0

# %%
final_df.dropna(inplace=True)

# %%
final_df = final_df[final_df['balls_left']!=0]

# %%
final_df.tail()
# Out:
#                batting_team    bowling_team       city  runs_left  balls_left  \
# 141977  Chennai Super Kings  Mumbai Indians  Hyderabad          1           5
# 141978  Chennai Super Kings  Mumbai Indians  Hyderabad          0           4
# 141979  Chennai Super Kings  Mumbai Indians  Hyderabad         -2           3
# 141980  Chennai Super Kings  Mumbai Indians  Hyderabad         -3           2
# 141981  Chennai Super Kings  Mumbai Indians  Hyderabad         -5           1
#
#         wickets  total_runs_x       crr   rrr  result
# 141977        5           152  7.878261   1.2       0
# 141978        5           152  7.862069   0.0       0
# 141979        5           152  7.897436  -4.0       0
# 141980        4           152  7.881356  -9.0       0
# 141981        4           152  7.915966 -30.0       0

# %% [markdown]
# ## Hence final_df is the final cleaned dataset
